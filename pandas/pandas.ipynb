# %%
import pandas as pd

# %%
#dataframe
info={
    "name":["Mursalin","shuvo","zia","imtiaz"],
    "cgpa":[3.00,3.10,3.76,3]
}
df=pd.DataFrame(info)
print(df)
df
# Out:
#        name  cgpa
# 0  Mursalin  3.00
# 1     shuvo  3.10
# 2       zia  3.76
# 3    imtiaz  3.00
#        name  cgpa
# 0  Mursalin  3.00
# 1     shuvo  3.10
# 2       zia  3.76
# 3    imtiaz  3.00

# %%
#series
s=pd.Series([1,2,3,4,5])
# print(s)
# print(s[0])

age=pd.Series([22,23,45,33],index=["shuvo","mursalin","zia","imtiaz"])
age
print(age["zia"])
# Out:
# 45

# %%
#series   properties,homogenous
s1=pd.Series([1,2,3,45])
s1[0]=100
print(s1)
s1.drop(0, inplace=True)
print(len(s1))
# Out:
# 0    100
# 1      2
# 2      3
# 3     45
# dtype: int64
# 3

# %%
s1=pd.Series([1,2,3,45])

s2 = s1.drop(0)   # নতুন series

# check original series size
print("\nOriginal series still has size:", len(s1))
# Out:
# Original series still has size: 4

# %%
#datafrane2
info={
    "name":["adam","Eve","Bob"],
    "age":[23,24,26],
    "gpa":[9.5,9.7,9.3]

}
df=pd.DataFrame(info)
print(df)
# Out:
#    name  age  gpa
# 0  adam   23  9.5
# 1   Eve   24  9.7
# 2   Bob   26  9.3

# %%
df=pd.DataFrame([["Adam",23],["Bob",44],["shuvo",66]],columns=["name","age"])
df
# Out:
#     name  age
# 0   Adam   23
# 1    Bob   44
# 2  shuvo   66

# %%
 df=pd.read_csv("raw_data.csv")
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#methods
df.head()
df.tail()
df.sample()  #  random  row
# Out:
#    id  name  age country   gender   income
# 3   3  Alex  NaN     USA  Unknown  47000.0

# %%
# df.info()
# df.shape
df.describe()
df.nunique()
# Out:
# id         10
# name        9
# age         6
# country     6
# gender      3
# income      8
# dtype: int64

# %%
df=pd.read_csv()

# %%
#selcting  dada 
# df[["country","income"]]
#row
#df.loc[2]  #  specfic  row
#df.loc[0:2]  #  specfic  row slice
#df.iloc[2]
#df.iloc[0:2]
# df.loc[0:2,["age","gender"]]
# df.iloc[0:3,2]
# df.iloc[:,1:5]  #  print  colum  1to  5   and  all row
# df.at[0,"name"]
# df.iat[0,1]
# df.loc[0, 'city'] = 'Dhaka'
# # df["name"]
# print(df.index)
# names=df["name"]
# names[0]="shuvo"
# n=df["name"].copy()
# names[0]="sljhlh"
# df
# Out:
# C:\Users\progr\AppData\Local\Temp\ipykernel_10296\2232371951.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   names[0]="sljhlh"
#     id      name   age country   gender   income   city
# 0    1    sljhlh  29.0     USA     Male  55000.0  Dhaka
# 1    1  Mursalin  29.0     USA     Male  55000.0    NaN
# 2    2  Mursalin   NaN  Canada   Female  62000.0    NaN
# 3    3  Mursalin   NaN     USA  Unknown  47000.0    NaN
# 4    4  Mursalin  34.0   Spain   Female      NaN    NaN
# 5    5  Mursalin  27.0   China     Male  51000.0    NaN
# 6    6  Mursalin  45.0   India   Female  73000.0    NaN
# 7    7  Mursalin  38.0     NaN     Male  68000.0    NaN
# 8    8  Mursalin  29.0     USA   Female  62000.0    NaN
# 9    9  Mursalin   NaN  Mexico     Male  45000.0    NaN
# ...

# %%
life_expectancy_rate=pd.read_csv("Life Expectancy Data (1).csv")
life_expectancy_rate.head(10)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
# 7  Afghanistan  2008  Developing              58.1            287.0
# 8  Afghanistan  2007  Developing              57.5            295.0
# 9  Afghanistan  2006  Developing              57.3            295.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# ...

# %%
#filter
d1=pd.read_csv("employee_data.csv")
d = pd.DataFrame(d1)
#d[d["Salary"]>50000]
# d[(d["Salary"]>50000)  & ( d["Department"]=="IT")]
#d[(d["Salary"]>70000) ][["ID","Age"]]
api_data=d[(d["Salary"]>70000) ][["ID","Age"]]
#api_data.iloc[0]  #  this measns current array  index  0 
api_data.loc[3]  #  this measns only  previous  index  not   update  if  we  want  print  then  write  only previous  index  

#print(api_data)
d.query("ID"==1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10296\3842574526.py in ?()
#       8 #api_data.iloc[0]  #  this measns current array  index  0
#       9 api_data.loc[3]  #  this measns only  previous  index  not   update  if  we  want  print  then  write  only previous  index
#      10
#      11 #print(api_data)
# ---> 12 d.query("ID"==1)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, expr, inplace, **kwargs)
#    4816         """
#    4817         inplace = validate_bool_kwarg(inplace, "inplace")
#    4818         if not isinstance(expr, str):
#    4819             msg = f"expr must be a string to be evaluated, {type(expr)} given"
# -> 4820             raise ValueError(msg)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
#    4823         res = self.eval(expr, **kwargs)
# ...

# %%
d.query("ID==1")
# Out:
#    ID   Name  Age Department  Salary
# 0   1  Alice   25         HR   55000
