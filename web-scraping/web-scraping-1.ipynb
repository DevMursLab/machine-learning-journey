# %%
# !pip install  requests
# Out:
# Requirement already satisfied: requests in c:\users\progr\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\progr\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\progr\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\progr\anaconda3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\progr\anaconda3\lib\site-packages (from requests) (2025.11.12)

# %%
import  requests

# %%
URL="https://stephen-king-api.onrender.com/api/books"
res=requests.get(URL)
json_data=res.json()

# %%
import pandas as pd
data=pd.json_normalize(json_data["data"]);
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 import pandas as pd
# ----> 2 data=pd.json_normalize(json_data["data"]);
#       3 data
#
# NameError: name 'json_data' is not defined

# %%
#web  scraping
url1="https://www.scrapethissite.com/pages/simple/"
res1=requests.get(url1)
#res1
print(res1.text)#html content of the page as a string 
print(res1.content) # Raw bytes of the response
print(res1.headers)#Metadeta like content type ,server info etc.
# if res.staus_code==200 
    #print("right")

with open ("scraped_data/data1.html","w") as f:
    f.write(res1.text())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 #web  scraping
#       2 url1="https://www.scrapethissite.com/pages/simple/"
# ----> 3 res1=requests.get(url1)
#       4 #res1
#       5 print(res1.text)#html content of the page as a string
#
# NameError: name 'requests' is not defined

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\progr\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\progr\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

with open("scraped_data/data1.html", "r") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, "lxml")

# Print the entire HTML
print(soup)

# Or print it prettified
print(soup.prettify())

# %%
# with open("scraped_data/data2.html","r") as f:
#     html_content = f.read()
#     print(r1.text)

# %%
#web  scraping
url1="https://www.scrapethissite.com/pages/simple/"
r1=requests.get(url1)
#res1
# print(r1.text)#html content of the page as a string 
# print(res1.content) # Raw bytes of the response
# print(res1.headers)#Metadeta like content type ,server info etc.
# # if res.staus_code==200 
#     #print("right")

with open("scraped_data/data2.html", "w", encoding="utf-8") as f:
    f.write(r1.text)

# %%
from bs4 import BeautifulSoup
with open ("scraped_data/data2.html","r") as f:
    html_content=f.read()
soup=BeautifulSoup(html_content,"lxml")
# soup
#type(soup)#bs4.BeautifulSoup
# soup.find("div")
all_h3=soup.find_all("h3")
all_countries=[]
for h3 in all_h3:
   name=(h3.get_text(strip=True))
   # print(h3.find_parent("div")["class"])
   population=(h3.find_next("div").select("span.country-population")[0].get_text(strip=True))
   all_countries.append([name,population])
all_countries
import pandas as pd
df=pd.DataFrame(all_countries,columns=["name","population"])
d
# Out:
#                      name population
# 0                 Andorra      84000
# 1    United Arab Emirates    4975593
# 2             Afghanistan   29121286
# 3     Antigua and Barbuda      86754
# 4                Anguilla      13254
# ..                    ...        ...
# 245                 Yemen   23495361
# 246               Mayotte     159042
# 247          South Africa   49000000
# 248                Zambia   13460305
# 249              Zimbabwe   11651858
#
# [250 rows x 2 columns]

# %%
df.to_csv("cleaned_data/data.csv",index=False)
